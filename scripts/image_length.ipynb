# %%
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from datetime import datetime, timedelta
from IPython.display import HTML

# %matplotlib widget

def load_gps_data(file_path):
    """JSONファイルからGPSデータを読み込む"""
    try:
        with open(file_path, 'r') as f:
            raw_data = json.load(f)
        
        processed = []
        for entry in raw_data:
            try:
                time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)
                lat = float(entry['latitude'])
                lon = float(entry['longitude'])
                image_length = int(entry.get('imageLength', '0'))
                processed.append({'time': time, 'lat': lat, 'lon': lon, 'image_length': image_length})
            except (KeyError, ValueError) as e:
                print(f"スキップされた不正なデータ: {entry} | エラー: {e}")
        
        return sorted(processed, key=lambda x: x['time'])
    
    except Exception as e:
        print(f"エラー発生: {str(e)}")
        return []

gps_data = load_gps_data("C:\\Users\\showe\\Desktop\\experiment\\clean\\2025_01_30\\miyakita5185.json")
# Out:
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738205220332', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738205220387} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738205220490} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'endpointFound', 'unixTime': 1738205220996} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738205222133} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738205222824} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738205222977} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738205230429} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738205230430} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738205230909} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'connected', 'unixTime': 1738205233073} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendStart', 'unixTime': 1738205233254} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendFinish', 'unixTime': 1738205242224} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'disconnectTo', 'unixTime': 1738205242434} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'discconected', 'unixTime': 1738205242816} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'connected', 'unixTime': 1738205243318} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendStart', 'unixTime': 1738205243511} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendFinish', 'unixTime': 1738205251387} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'disconnectTo', 'unixTime': 1738205251976} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'discconected', 'unixTime': 1738205252376} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'connected', 'unixTime': 1738205256449} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'sendStart', 'unixTime': 1738205256500} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'sendFinish', 'unixTime': 1738205266853} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'discconected', 'unixTime': 1738205270028} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738205530342} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738205530345} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738205530361} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738205530366} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'connected', 'unixTime': 1738205623053} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'sendStart', 'unixTime': 1738205623227} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'discconected', 'unixTime': 1738205639839} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'connected', 'unixTime': 1738205732805} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'sendStart', 'unixTime': 1738205732838} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'discconected', 'unixTime': 1738205754452} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'connected', 'unixTime': 1738205837862} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'sendStart', 'unixTime': 1738205837955} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'discconected', 'unixTime': 1738205856753} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738206615235', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738206679387', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738206679923} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738206680024} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738206680129} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'endpointFound', 'unixTime': 1738206680438} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738206680647} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'connected', 'unixTime': 1738206683577} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendStart', 'unixTime': 1738206683768} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendFinish', 'unixTime': 1738206702307} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'disconnectTo', 'unixTime': 1738206702308} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'discconected', 'unixTime': 1738206702792} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'connected', 'unixTime': 1738206703367} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendStart', 'unixTime': 1738206703417} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendFinish', 'unixTime': 1738206712880} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'disconnectTo', 'unixTime': 1738206721611} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'discconected', 'unixTime': 1738206722148} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738206723211} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738206723382} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738206745869} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738206747125} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738206747665} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738206900226', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738206916544', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738206917201} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738206918369} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738206918418} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738206918724} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'endpointFound', 'unixTime': 1738206918740} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738206918817} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738206918834} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738206938591} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738206938592} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738206939305} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'connected', 'unixTime': 1738206943262} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendStart', 'unixTime': 1738206943394} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendFinish', 'unixTime': 1738206967893} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'disconnectTo', 'unixTime': 1738206969424} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'discconected', 'unixTime': 1738206969888} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'connected', 'unixTime': 1738206973568} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendStart', 'unixTime': 1738206973761} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendFinish', 'unixTime': 1738207001104} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'disconnectTo', 'unixTime': 1738207003297} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'discconected', 'unixTime': 1738207004052} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738207226581} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738207226598} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738207226599} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738207226599} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738207226599} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738207651240', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738207693850', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'endpointFound', 'unixTime': 1738207693902} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738207694727} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738207694828} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738207695126} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738207695335} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'connected', 'unixTime': 1738207698954} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendStart', 'unixTime': 1738207699103} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'sendFinish', 'unixTime': 1738207722008} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'disconnectTo', 'unixTime': 1738207722009} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6247', 'event': 'discconected', 'unixTime': 1738207722527} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'connected', 'unixTime': 1738207723898} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendStart', 'unixTime': 1738207724104} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendFinish', 'unixTime': 1738207724845} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'disconnectTo', 'unixTime': 1738207749673} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'discconected', 'unixTime': 1738207750216} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738207753622} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738207753766} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738207777608} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738207780596} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738207781149} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208003894} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208003911} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208003912} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208003912} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208003913} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738208132228', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738208185883', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738208187170} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738208187198} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738208187266} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738208188304} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738208188884} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738208188935} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738208212216} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738208212217} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738208212704} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'connected', 'unixTime': 1738208214010} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendStart', 'unixTime': 1738208214151} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'sendFinish', 'unixTime': 1738208240662} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'disconnectTo', 'unixTime': 1738208240806} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'discconected', 'unixTime': 1738208241189} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208495920} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208495936} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208495937} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738208495938} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738209215234', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738209246444', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738209247644} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738209247663} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738209247953} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738209248870} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738209249943} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738209250136} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738209263218', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738209267284', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'endpointFound', 'unixTime': 1738209268328} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'endpointFound', 'unixTime': 1738209268632} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita9301', 'event': 'endpointFound', 'unixTime': 1738209269350} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita1066', 'event': 'endpointFound', 'unixTime': 1738209270179} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738209280804} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738209280805} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738209281175} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'connected', 'unixTime': 1738209284569} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendStart', 'unixTime': 1738209284759} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'sendFinish', 'unixTime': 1738209318180} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'disconnectTo', 'unixTime': 1738209318180} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita6003', 'event': 'discconected', 'unixTime': 1738209318929} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'error', 'event': 'endpointLost', 'unixTime': 1738209619823} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738210506221', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738210561303', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'connected', 'unixTime': 1738210564272} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'sendStart', 'unixTime': 1738210564397} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'sendFinish', 'unixTime': 1738210564654} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'to': 'miyakita101', 'event': 'discconected', 'unixTime': 1738210565652} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738210674234', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738211088930', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738211191227', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738211228799', 'event': 'startSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738211252237', 'event': 'stopSearch'} | エラー: 'latitude'
# スキップされた不正なデータ: {'from': 'miyakita5185', 'unixTime': '1738211307888', 'event': 'startSearch'} | エラー: 'latitude'
# C:\Users\showe\AppData\Local\Temp\ipykernel_5024\1414033135.py:19: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)

# %%
if not gps_data:
    print("有効なデータがありません")
else:
    # 中心座標を指定
    centerLatitude = 37.86678
    centerLongitude = 138.93920
    
    # 正方形の範囲を定義
    half_side = 0.001
    xlim = [centerLongitude - half_side, centerLongitude + half_side]
    ylim = [centerLatitude - half_side, centerLatitude + half_side]

    # 全体の範囲を取得（余裕を持たせた範囲）
    all_lons = [d['lon'] for d in gps_data]
    all_lats = [d['lat'] for d in gps_data]
    ax.set_xlim(min(all_lons)-0.001, max(all_lons)+0.001)
    ax.set_ylim(min(all_lats)-0.001, max(all_lats)+0.001)

    # プロットの準備
    plt.rcParams["font.size"] = 30
    plt.rcParams["font.family"] = "HackGen Console NF"
    fig, ax = plt.subplots(figsize=(17, 12))
    point = ax.scatter([], [], c='r', s=100, edgecolors='k', zorder=3)

    # 正方形を描画
    square_x = [xlim[0], xlim[1], xlim[1], xlim[0], xlim[0]]
    square_y = [ylim[0], ylim[0], ylim[1], ylim[1], ylim[0]]
    ax.plot(square_x, square_y, 'k--', alpha=0.5)

    # 軸の設定
    ax.xaxis.set_major_locator(mticker.MultipleLocator(0.0005))
    ax.yaxis.set_major_locator(mticker.MultipleLocator(0.0005))
    ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.4f'))
    ax.yaxis.set_major_formatter(mticker.FormatStrFormatter('%.4f'))
    ax.set_xlabel("経度", fontsize=30)  # x軸のラベルのフォントサイズを変更
    ax.set_ylabel("緯度", fontsize=30)  # y軸のラベルのフォントサイズを変更
    ax.tick_params(axis='both', labelsize=30)

    def update(frame):
        if frame >= len(gps_data):
            return point,  # もうデータがない場合
        
        current = gps_data[frame]  # 現在のフレームのデータを取得
        lon = current['lon']
        lat = current['lat']
        image_length = current['image_length']  # 現在の点のimageLength
        color = 'r' if image_length > 0 else 'gray'  # imageLengthが1以上なら赤、0なら灰色
        
        # 点の位置と色を更新
        point.set_offsets(np.c_[lon, lat])
        point.set_color(color)
        
        # タイトルを更新
        ax.set_title(f"{current['time'].strftime('%Y-%m-%d %H:%M:%S')}\n")
        
        return point,

    ani = animation.FuncAnimation(
        fig, update,
        frames=len(gps_data),
        interval=50,
        blit=False
    )
    
    # アニメーションを保存
    ani.save('anim.mp4', writer="ffmpeg")
    #plt.show()
    #HTML(ani.to_html5_video())
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import os
import glob
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from datetime import datetime, timedelta
from IPython.display import HTML

def load_gps_data(file_path):
    try:
        with open(file_path, 'r') as f:
            raw_data = json.load(f)
        processed = []
        for entry in raw_data:
            try:
                time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)
                lat = float(entry['latitude'])
                lon = float(entry['longitude'])
                image_length = int(entry.get('imageLength', '0'))
                processed.append({'time': time, 'lat': lat, 'lon': lon, 'image_length': image_length})
            except (KeyError, ValueError):
                pass
        return sorted(processed, key=lambda x: x['time'])
    except:
        return []

data_dir = "C:\\Users\\showe\\Desktop\\experiment\\clean\\2025_01_30"
json_files = glob.glob(os.path.join(data_dir, "*.json"))
all_gps_data = [load_gps_data(f) for f in json_files]
all_gps_data = [d for d in all_gps_data if d]
# Out:
# C:\Users\showe\AppData\Local\Temp\ipykernel_5024\2467559883.py:17: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)

# %%
# ...existing code...
import matplotlib.ticker as mticker


if not all_gps_data:
    print("有効なデータがありません")
else:
    # 全データから最小・最大時刻を算出
    min_time = min(min(d['time'] for d in ds) for ds in all_gps_data)
    max_time = max(max(d['time'] for d in ds) for ds in all_gps_data)

    # 10秒刻みのタイムリストを生成
    frame_times = []
    current = min_time
    while current <= max_time:
        frame_times.append(current)
        current += timedelta(seconds=10)

    # グラフ初期化
    plt.rcParams["font.size"] = 20
    plt.rcParams["font.family"] = "HackGen Console NF"
    fig, ax = plt.subplots(figsize=(9, 6))
    scatter_list = []
    colors = plt.cm.rainbow(np.linspace(0, 1, len(all_gps_data)))
    for c in colors:
        scatter_list.append(ax.scatter([], [], c=[c], s=100, edgecolors='k', zorder=3))

    # 描画範囲設定
    all_lons = [d['lon'] for ds in all_gps_data for d in ds]
    all_lats = [d['lat'] for ds in all_gps_data for d in ds]
    #ax.set_xlim(min(all_lons) - 0.001, max(all_lons) + 0.001)
    #ax.set_ylim(min(all_lats) - 0.001, max(all_lats) + 0.001)
    ax.set_xlim(138.939 - 0.002, 138.939 + 0.002)
    ax.set_ylim(37.867 - 0.002, 37.867 + 0.002)
    
    # 軸の設定
    ax.xaxis.set_major_locator(mticker.MultipleLocator(0.001))
    ax.yaxis.set_major_locator(mticker.MultipleLocator(0.001))
    ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.4f'))
    ax.yaxis.set_major_formatter(mticker.FormatStrFormatter('%.4f'))
    ax.set_xlabel("経度", fontsize=30)  # x軸のラベルのフォントサイズを変更
    ax.set_ylabel("緯度", fontsize=30)  # y軸のラベルのフォントサイズを変更
    ax.tick_params(axis='both', labelsize=30)

    ax.xaxis.set_major_formatter(mticker.FormatStrFormatter('%.3f'))
    ax.yaxis.set_major_formatter(mticker.FormatStrFormatter('%.3f'))

    """
    rectangle_min_lons = 138.939 - 0.01
    rectangle_max_lons = 138.939 + 0.01
    rectangle_min_lats = 37.8668 - 0.01
    rectangle_max_lats = 37.8668 + 0.01

    rectangle_lons = [rectangle_max_lons, rectangle_min_lons, rectangle_min_lons, rectangle_max_lons, rectangle_max_lons]
    rectangle_lats = [rectangle_max_lats, rectangle_max_lats, rectangle_min_lats, rectangle_min_lats, rectangle_max_lats]
    """

    rectangle_lons = [138.9402, 138.9382, 138.9382, 138.9402, 138.9402]
    rectangle_lats = [37.86778, 37.86778, 37.86578, 37.86578, 37.86778]
    ax.plot(rectangle_lons, rectangle_lats, 'k--', alpha=0.5)

    # 指定時刻以下で最も近いポイントを取得する関数
    def get_position_at_time(dataset, t):
        vals = [p for p in dataset if p['time'] <= t]
        if not vals:  # データが無い場合はNone
            return None
        return vals[-1]  # 時間がt以下のうち最後の要素

    def update(frame):
        t = frame_times[frame]
        for i, ds in enumerate(all_gps_data):
            pos = get_position_at_time(ds, t)
            if pos:
                scatter_list[i].set_offsets(np.c_[pos['lon'], pos['lat']])
                color = 'r' if pos['image_length'] > 0 else 'gray'
                scatter_list[i].set_color(color)
        ax.set_title(f"{t.strftime('%Y-%m-%d %H:%M:%S')}")
        return scatter_list

    ani = animation.FuncAnimation(
        fig, update,
        frames=len(frame_times),
        interval=50,
        blit=False,
        
    )
    ani.save('anim_multi_synced2.mp4', writer='ffmpeg')

# ...existing code...
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 80
#      77         ax.set_title(f"{t.strftime('%Y-%m-%d %H:%M:%S')}")
#      78         return scatter_list
# ---> 80     ani = animation.FuncAnimation(
#      81         fig, update,
#      82         frames=len(frame_times),
#      83         interval=50,
#      84         blit=False,
#      85         bbox_inches='tight'
#      86     )
#      87     ani.save('anim_multi_synced2.mp4', writer='ffmpeg')
#      89 # ...existing code...
#
# File c:\Users\showe\Desktop\experiment\scripts\.venv\Lib\site-packages\matplotlib\animation.py:1716, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1713 # Needs to be initialized so the draw functions work without checking
#    1714 self._save_seq = []
# -> 1716 super().__init__(fig, **kwargs)
#    1718 # Need to reset the saved seq, since right now it will contain data
#    1719 # for a single frame from init, which is not what we want.
#    1720 self._save_seq = []
#
# File c:\Users\showe\Desktop\experiment\scripts\.venv\Lib\site-packages\matplotlib\animation.py:1440, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1438 if event_source is None:
#    1439     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1440 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# TypeError: Animation.__init__() got an unexpected keyword argument 'bbox_inches'
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import os
import glob
import json
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from datetime import datetime, timedelta
import matplotlib.dates as mdates

def load_gps_data(file_path):
    try:
        with open(file_path, 'r') as f:
            raw_data = json.load(f)
        processed = []
        for entry in raw_data:
            try:
                time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)
                lat = float(entry['latitude'])
                lon = float(entry['longitude'])
                image_length = int(entry.get('imageLength', '0'))
                processed.append({'time': time, 'lat': lat, 'lon': lon, 'image_length': image_length})
            except (KeyError, ValueError):
                pass
        return sorted(processed, key=lambda x: x['time'])
    except:
        return []

data_dir = "C:\\Users\\showe\\Desktop\\experiment\\clean\\2025_01_30"
json_files = glob.glob(os.path.join(data_dir, "*.json"))
all_gps_data = [load_gps_data(f) for f in json_files]
print(all_gps_data)

# 全データから最小・最大時刻を算出
min_time = min(min(d['time'] for d in ds) for ds in all_gps_data)
max_time = max(max(d['time'] for d in ds) for ds in all_gps_data)

# 10秒刻みのタイムリストを生成
frame_times = []
current = min_time
while current <= max_time:
    frame_times.append(current)
    current += timedelta(seconds=10)

def get_imageLength_at_time(dataset, t):
    vals = [p for p in dataset if p['time'] <= t]
    if not vals:  # データが無い場合はNone
        return None
    return vals[-1]  # 時間がt以下のうち最後の要素

plt.rcParams["font.size"] = 18
plt.rcParams["font.family"] = "HackGen Console NF"
plt.figure(figsize=(10, 5))

colors = ['r', 'g', 'b', 'c', 'm', 'y', 'k', 'w']

for idx, data in enumerate(all_gps_data):

    results = []

    for time in frame_times:
        pos = get_imageLength_at_time(data, time)
        length = pos['image_length'] if pos else 0
        results.append((time, length))

    for i in range(len(results) - 1):
        if i == 0:
            continue
        if results[i][1] * results[i - 1][1] > 0:
            plt.plot([results[i][0], results[i-1][0]], [idx, idx], color=colors[idx], linewidth=2)

plt.xlabel('時間')
plt.ylabel('端末名')
plt.title('情報フローティングの継続')
plt.grid(True)

plt.xlim(min_time, max_time + timedelta(seconds=10)) 

# 時間のみを表示するフォーマットに設定
time_fmt = mdates.DateFormatter('%H:%M')
plt.gca().xaxis.set_major_formatter(time_fmt)
plt.show()
# Out:
# C:\Users\showe\AppData\Local\Temp\ipykernel_17732\3462547583.py:17: DeprecationWarning: datetime.datetime.utcfromtimestamp() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.fromtimestamp(timestamp, datetime.UTC).
#   time = datetime.utcfromtimestamp(int(entry['unixTime'])/1000)+ timedelta(hours=9)
# [[{'time': datetime.datetime(2025, 1, 30, 11, 46, 37, 372000), 'lat': 37.8669879, 'lon': 138.9392585, 'image_length': 0}, {'time': datetime.datetime(2025, 1, 30, 11, 46, 41, 214000), 'lat': 37.8669879, 'lon': 138.9392585, 'image_length': 0}, {'time': datetime.datetime(2025, 1, 30, 11, 46, 47, 14000), 'lat': 37.8669775, 'lon': 138.9392728, 'image_length': 0}, {'time': datetime.datetime(2025, 1, 30, 11, 46, 51, 277000), 'lat': 37.8669872, 'lon': 138.9392531, 'image_length': 0}, {'time': datetime.datetime(2025, 1, 30, 11, 46, 57, 20000), 'lat': 37.8669805, 'lon': 138.9392701, 'image_length': 0}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 1, 311000), 'lat': 37.866987, 'lon': 138.9392505, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 5, 662000), 'lat': 37.8669751, 'lon': 138.9393572, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 8, 664000), 'lat': 37.8669817, 'lon': 138.9393597, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 11, 342000), 'lat': 37.8669816, 'lon': 138.939321, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 13, 685000), 'lat': 37.8669798, 'lon': 138.9393051, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 16, 681000), 'lat': 37.8669827, 'lon': 138.9393315, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 19, 679000), 'lat': 37.8669916, 'lon': 138.9393386, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 22, 691000), 'lat': 37.8670235, 'lon': 138.9394286, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 25, 663000), 'lat': 37.8670206, 'lon': 138.9394156, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 28, 680000), 'lat': 37.8670566, 'lon': 138.939407, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 31, 427000), 'lat': 37.8669909, 'lon': 138.9394118, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 33, 692000), 'lat': 37.8669696, 'lon': 138.9394116, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 36, 676000), 'lat': 37.8669775, 'lon': 138.939407, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 39, 690000), 'lat': 37.8669783, 'lon': 138.9394067, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 42, 686000), 'lat': 37.8669087, 'lon': 138.9394164, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 45, 673000), 'lat': 37.8669102, 'lon': 138.9394268, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 48, 687000), 'lat': 37.866868, 'lon': 138.9394245, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 51, 474000), 'lat': 37.866833, 'lon': 138.9394314, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 53, 675000), 'lat': 37.8667916, 'lon': 138.9394554, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 56, 690000), 'lat': 37.8667418, 'lon': 138.9394542, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 47, 59, 688000), 'lat': 37.8667581, 'lon': 138.9394665, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 2, 689000), 'lat': 37.8667662, 'lon': 138.9394798, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 5, 693000), 'lat': 37.866803, 'lon': 138.9394855, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 8, 672000), 'lat': 37.8668096, 'lon': 138.939483, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 11, 578000), 'lat': 37.8668241, 'lon': 138.9394833, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 14, 677000), 'lat': 37.866825, 'lon': 138.9394833, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 17, 373000), 'lat': 37.866825, 'lon': 138.9394833, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 19, 678000), 'lat': 37.8667797, 'lon': 138.9394906, 'image_length': 1}, {'time': datetime.datetime(2025, 1, 30, 11, 48, 22, 6780 ...
